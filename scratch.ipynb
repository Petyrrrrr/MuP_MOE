# %%
exec(open('configurator.py').read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 exec(open('configurator.py').read())
#
# File <string>:47
#
# ValueError: Unknown config key: f
